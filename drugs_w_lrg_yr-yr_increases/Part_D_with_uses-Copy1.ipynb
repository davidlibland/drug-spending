# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.options.display.max_columns = 120

# %%
df_part_d = pd.read_csv('https://query.data.world/s/1jckku39d0p78m8jm1gnvww5t')
df_part_d.head(5)
# Out:
#                   Brand Name                     Generic Name  \
# 0                   10 WASH             SULFACETAMIDE SODIUM
# 1  1ST TIER UNIFINE PENTIPS             PEN NEEDLE, DIABETIC
# 2          ABILIFY DISCMELT                     ARIPIPRAZOLE
# 3              AK-PENTOLATE               CYCLOPENTOLATE HCL
# 4                     DDAVP   DESMOPRESSIN (NONREFRIGERATED)
#
#    Claim Count, 2011  Total Spending, 2011  Beneficiary Count, 2011  \
# 0               24.0               1569.19                     16.0
# 1             2472.0              57666.73                    893.0
# 2             4677.0            3929705.80                    961.0
# 3              730.0               6893.65                    563.0
# 4             1044.0             599877.67                    194.0
#
#    Total Annual Spending Per User, 2011  Unit Count, 2011  \
# 0                             98.074375            5170.0
# 1                             64.576405          293160.0
# 2                           4089.183975          189351.5
# 3                             12.244494            2019.0
# 4                           3092.152938           13261.0
#
#    Average Cost Per Unit (Weighted), 2011  Beneficiary Count No LIS, 2011  \
# 0                                0.303518                             NaN
# 1                                0.196766                           422.0
# 2                               20.753897                            83.0
# 3                                3.414388                           369.0
# 4                               45.236232                            75.0
#
#    Average Beneficiary Cost Share No LIS, 2011  Beneficiary Count LIS, 2011  \
# 0                                          NaN                          NaN
# 1                                    42.347204                        471.0
# 2                                   439.876386                        878.0
# 3                                     7.194173                        194.0
# 4                                   372.349733                        119.0
#
#    Average Beneficiary Cost Share LIS, 2011  Claim Count, 2012  \
# 0                                       NaN                NaN
# 1                                  7.545860             3486.0
# 2                                 22.165581             4705.0
# 3                                  1.993557              320.0
# 4                                 14.688319             1001.0
#
#    Total Spending, 2012  Beneficiary Count, 2012  \
# 0                   NaN                      NaN
# 1              75786.01                   1261.0
# 2            4529795.27                    915.0
# 3               3501.42                    246.0
# 4             664332.10                    193.0
#
#    Total Annual Spending Per User, 2012  Unit Count, 2012  \
# 0                                   NaN               NaN
# 1                             60.099929          405484.0
# 2                           4950.595924          192615.5
# 3                             14.233415             852.0
# 4                           3442.135233           13440.0
#
#    Average Cost Per Unit (Weighted), 2012  Beneficiary Count No LIS, 2012  \
# 0                                     NaN                             NaN
# 1                                0.186918                           607.0
# 2                               23.522216                            89.0
# 3                                4.109648                           175.0
# 4                               49.429472                            77.0
#
#    Average Beneficiary Cost Share No LIS, 2012  Beneficiary Count LIS, 2012  \
# 0                                          NaN                          NaN
# 1                                    38.242323                        654.0
# 2                                   440.755955                        826.0
# 3                                     8.420971                         71.0
# 4                                   457.663766                        116.0
#
#    Average Beneficiary Cost Share LIS, 2012  Claim Count, 2013  \
# 0                                       NaN                NaN
# 1                                  6.501223             4413.0
# 2                                 12.490230             5033.0
# 3                                  3.000423                NaN
# 4                                 21.710345             1032.0
#
#    Total Spending, 2013  Beneficiary Count, 2013  \
# 0                   NaN                      NaN
# 1              95304.09                   1633.0
# 2            5221987.76                    967.0
# 3                   NaN                      NaN
# 4             886774.59                    202.0
#
#    Total Annual Spending Per User, 2013  Unit Count, 2013  \
# 0                                   NaN               NaN
# 1                             58.361353          522780.0
# 2                           5400.194167          193300.0
# 3                                   NaN               NaN
# 4                           4389.973218           15312.0
#
#    Average Cost Per Unit (Weighted), 2013  Beneficiary Count No LIS, 2013  \
# 0                                     NaN                             NaN
# 1                                0.182282                           833.0
# 2                               27.019006                            74.0
# 3                                     NaN                             NaN
# 4                               57.913701                            91.0
#
#    Average Beneficiary Cost Share No LIS, 2013  Beneficiary Count LIS, 2013  \
# 0                                          NaN                          NaN
# 1                                    35.618511                        800.0
# 2                                   493.977297                        893.0
# 3                                          NaN                          NaN
# 4                                   483.031099                        111.0
#
#    Average Beneficiary Cost Share LIS, 2013  Claim Count, 2014  \
# 0                                       NaN                NaN
# 1                                  5.880125             6788.0
# 2                                 12.986976             5186.0
# 3                                       NaN                NaN
# 4                                 16.434775              949.0
#
#    Total Spending, 2014  Beneficiary Count, 2014  \
# 0                   NaN                      NaN
# 1             150749.66                   2769.0
# 2            6282391.38                    951.0
# 3                   NaN                      NaN
# 4            1029916.62                    163.0
#
#    Total Annual Spending Per User, 2014  Unit Count, 2014  \
# 0                                   NaN               NaN
# 1                             54.441914          813255.0
# 2                           6606.089779          198161.0
# 3                                   NaN               NaN
# 4                           6318.506871           15115.0
#
#    Average Cost Per Unit (Weighted), 2014  Beneficiary Count No LIS, 2014  \
# 0                                     NaN                             NaN
# 1                                0.185352                          1481.0
# 2                               31.703590                            85.0
# 3                                     NaN                             NaN
# 4                               68.138711                            77.0
#
#    Average Beneficiary Cost Share No LIS, 2014  Beneficiary Count LIS, 2014  \
# 0                                          NaN                          NaN
# 1                                    32.143275                       1288.0
# 2                                   546.043176                        866.0
# 3                                          NaN                          NaN
# 4                                   643.323766                         86.0
#
#    Average Beneficiary Cost Share LIS, 2014  Claim Count, 2015  \
# 0                                       NaN                NaN
# 1                                  5.132989            10749.0
# 2                                 10.375242             2790.0
# 3                                       NaN                NaN
# 4                                 11.626163              798.0
#
#    Total Spending, 2015  Beneficiary Count, 2015  \
# 0                   NaN                      NaN
# 1             257895.63                   5173.0
# 2            3735192.84                    742.0
# 3                   NaN                      NaN
# 4             984371.25                    138.0
#
#    Total Annual Spending Per User, 2015  Unit Count, 2015  \
# 0                                   NaN               NaN
# 1                             49.854172         1335132.0
# 2                           5033.952615          102764.0
# 3                                   NaN               NaN
# 4                           7133.125000           13045.0
#
#    Average Cost Per Unit (Weighted), 2015  Beneficiary Count No LIS, 2015  \
# 0                                     NaN                             NaN
# 1                                0.193205                          2878.0
# 2                               36.344484                            53.0
# 3                                     NaN                             NaN
# 4                               75.459659                            62.0
#
#    Average Beneficiary Cost Share No LIS, 2015  Beneficiary Count LIS, 2015  \
# 0                                          NaN                          NaN
# 1                                    27.305271                       2295.0
# 2                                   663.647358                        689.0
# 3                                          NaN                          NaN
# 4                                   659.737903                         76.0
#
#    Average Beneficiary Cost Share LIS, 2015  \
# 0                                       NaN
# 1                                  3.987891
# 2                                 18.064644
# 3                                       NaN
# 4                                 11.679605
#
#    Annual Change in Average Cost Per Unit, 2015
# 0                                           NaN
# 1                                      0.022208
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN

# %% [markdown]
# Do a bit of cleaning:

# %%
df_part_d['Generic Name'] = df_part_d['Generic Name'].apply(lambda x: x.strip())
df_part_d['Generic Name'] = df_part_d['Generic Name'].apply(lambda x: x.replace('HCL','HYDROCHLORIDE'))
df_part_d['Generic Name'] = df_part_d['Generic Name'].apply(lambda x: x.replace('PHOSP','PHOSPHATE'))

# %%
df_nda = pd.read_csv('https://query.data.world/s/ehr2lcy24q98ew9nnubyd4t73')
df_nda.head(5)
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0002-1200_e62214a4-82fd-4e06-90a0-577a32fea93f  0002-1200
# 1  0002-1407_e7af3676-cd9d-4c30-b127-9f6c46ff1589  0002-1407
# 2  0002-1433_a084daa7-c0a0-4996-9fe0-3c1df22c01c7  0002-1433
# 3  0002-1434_a084daa7-c0a0-4996-9fe0-3c1df22c01c7  0002-1434
# 4  0002-1445_ad2261c2-3be8-4add-8274-0cc565d86ffb  0002-1445
#
#            PRODUCTTYPENAME      PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0  HUMAN PRESCRIPTION DRUG               Amyvid                   NaN
# 1  HUMAN PRESCRIPTION DRUG  Quinidine Gluconate                   NaN
# 2  HUMAN PRESCRIPTION DRUG            Trulicity                   NaN
# 3  HUMAN PRESCRIPTION DRUG            Trulicity                   NaN
# 4  HUMAN PRESCRIPTION DRUG                TALTZ                   NaN
#
#     NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 0     Florbetapir F 18  INJECTION, SOLUTION   INTRAVENOUS          20120601.0
# 1  Quinidine Gluconate             SOLUTION   INTRAVENOUS          19510301.0
# 2          Dulaglutide  INJECTION, SOLUTION  SUBCUTANEOUS          20141107.0
# 3          Dulaglutide  INJECTION, SOLUTION  SUBCUTANEOUS          20141107.0
# 4           ixekizumab  INJECTION, SOLUTION  SUBCUTANEOUS          20160322.0
#
#    ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 0               NaN                   NDA         NDA202008
# 1               NaN                   NDA         NDA007529
# 2               NaN                   BLA         BLA125469
# 3               NaN                   BLA         BLA125469
# 4               NaN                   BLA         BLA125521
#
#              LABELERNAME        SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 0  Eli Lilly and Company     FLORBETAPIR F-18                        51
# 1  Eli Lilly and Company  QUINIDINE GLUCONATE                        80
# 2  Eli Lilly and Company          DULAGLUTIDE                      0.75
# 3  Eli Lilly and Company          DULAGLUTIDE                       1.5
# 4  Eli Lilly and Company           IXEKIZUMAB                        80
#
#   ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 0             mCi/mL  Radioactive Diagnostic Agent [EPC],Positron Em...
# 1              mg/mL  Antiarrhythmic [EPC],Cytochrome P450 2D6 Inhib...
# 2            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
# 3            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
# 4              mg/mL  Interleukin-17A Antagonist [EPC],Interleukin-1...
#
#   DEASCHEDULE
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_nda['NONPROPRIETARYNAME'] = df_nda['NONPROPRIETARYNAME'].apply( lambda x: str(x).upper())
df_nda.head(5)
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0002-1200_e62214a4-82fd-4e06-90a0-577a32fea93f  0002-1200
# 1  0002-1407_e7af3676-cd9d-4c30-b127-9f6c46ff1589  0002-1407
# 2  0002-1433_a084daa7-c0a0-4996-9fe0-3c1df22c01c7  0002-1433
# 3  0002-1434_a084daa7-c0a0-4996-9fe0-3c1df22c01c7  0002-1434
# 4  0002-1445_ad2261c2-3be8-4add-8274-0cc565d86ffb  0002-1445
#
#            PRODUCTTYPENAME      PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0  HUMAN PRESCRIPTION DRUG               Amyvid                   NaN
# 1  HUMAN PRESCRIPTION DRUG  Quinidine Gluconate                   NaN
# 2  HUMAN PRESCRIPTION DRUG            Trulicity                   NaN
# 3  HUMAN PRESCRIPTION DRUG            Trulicity                   NaN
# 4  HUMAN PRESCRIPTION DRUG                TALTZ                   NaN
#
#     NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 0     FLORBETAPIR F 18  INJECTION, SOLUTION   INTRAVENOUS          20120601.0
# 1  QUINIDINE GLUCONATE             SOLUTION   INTRAVENOUS          19510301.0
# 2          DULAGLUTIDE  INJECTION, SOLUTION  SUBCUTANEOUS          20141107.0
# 3          DULAGLUTIDE  INJECTION, SOLUTION  SUBCUTANEOUS          20141107.0
# 4           IXEKIZUMAB  INJECTION, SOLUTION  SUBCUTANEOUS          20160322.0
#
#    ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 0               NaN                   NDA         NDA202008
# 1               NaN                   NDA         NDA007529
# 2               NaN                   BLA         BLA125469
# 3               NaN                   BLA         BLA125469
# 4               NaN                   BLA         BLA125521
#
#              LABELERNAME        SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 0  Eli Lilly and Company     FLORBETAPIR F-18                        51
# 1  Eli Lilly and Company  QUINIDINE GLUCONATE                        80
# 2  Eli Lilly and Company          DULAGLUTIDE                      0.75
# 3  Eli Lilly and Company          DULAGLUTIDE                       1.5
# 4  Eli Lilly and Company           IXEKIZUMAB                        80
#
#   ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 0             mCi/mL  Radioactive Diagnostic Agent [EPC],Positron Em...
# 1              mg/mL  Antiarrhythmic [EPC],Cytochrome P450 2D6 Inhib...
# 2            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
# 3            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
# 4              mg/mL  Interleukin-17A Antagonist [EPC],Interleukin-1...
#
#   DEASCHEDULE
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_generic_to_use = df_nda[['NONPROPRIETARYNAME','PHARM_CLASSES']].drop_duplicates()
df_generic_to_use.head()
# Out:
#     NONPROPRIETARYNAME                                      PHARM_CLASSES
# 0     FLORBETAPIR F 18  Radioactive Diagnostic Agent [EPC],Positron Em...
# 1  QUINIDINE GLUCONATE  Antiarrhythmic [EPC],Cytochrome P450 2D6 Inhib...
# 2          DULAGLUTIDE  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
# 4           IXEKIZUMAB  Interleukin-17A Antagonist [EPC],Interleukin-1...
# 5         TESTOSTERONE  Androgen [EPC],Androgen Receptor Agonists [MoA...

# %%
df = pd.merge(left = df_part_d, right = df_generic_to_use,how='left',left_on='Generic Name',right_on='NONPROPRIETARYNAME')

# %%
df.sort_values(by='PHARM_CLASSES',inplace = True)
df.drop_duplicates(subset = ['Brand Name','Generic Name'],inplace=True)
df.head()
# Out:
#         Brand Name Generic Name  Claim Count, 2011  Total Spending, 2011  \
# 4388     ZYFLO CR      ZILEUTON             7478.0          5.142822e+06
# 4387        ZYFLO      ZILEUTON              484.0          2.632957e+05
# 3183      AVODART   DUTASTERIDE          1631984.0          2.529732e+08
# 302   DUTASTERIDE   DUTASTERIDE                NaN                   NaN
# 631   FINASTERIDE   FINASTERIDE          3392755.0          1.652143e+08
#
#       Beneficiary Count, 2011  Total Annual Spending Per User, 2011  \
# 4388                   1750.0                           2938.755543
# 4387                    200.0                           1316.478300
# 3183                 300083.0                            843.010792
# 302                       NaN                                   NaN
# 631                  645474.0                            255.958055
#
#       Unit Count, 2011  Average Cost Per Unit (Weighted), 2011  \
# 4388      9.453600e+05                                5.440067
# 4387      5.246700e+04                                5.018310
# 3183      6.899748e+07                                3.666412
# 302                NaN                                     NaN
# 631       1.655944e+08                                0.997704
#
#       Beneficiary Count No LIS, 2011  \
# 4388                           817.0
# 4387                            86.0
# 3183                        200809.0
# 302                              NaN
# 631                         493303.0
#
#       Average Beneficiary Cost Share No LIS, 2011  \
# 4388                                   503.209045
# 4387                                   308.680698
# 3183                                   270.093709
# 302                                           NaN
# 631                                     58.375047
#
#       Beneficiary Count LIS, 2011  Average Beneficiary Cost Share LIS, 2011  \
# 4388                        933.0                                 16.471961
# 4387                        114.0                                  7.955263
# 3183                      99274.0                                 25.873865
# 302                           NaN                                       NaN
# 631                      152171.0                                  7.982504
#
#       Claim Count, 2012  Total Spending, 2012  Beneficiary Count, 2012  \
# 4388             7687.0          9.477538e+06                   1734.0
# 4387              623.0          6.703242e+05                    182.0
# 3183          1533625.0          2.626614e+08                 279995.0
# 302                 NaN                   NaN                      NaN
# 631           3748171.0          1.242199e+08                 728822.0
#
#       Total Annual Spending Per User, 2012  Unit Count, 2012  \
# 4388                           5465.708431      9.893500e+05
# 4387                           3683.100000      6.814200e+04
# 3183                            938.093097      6.709854e+07
# 302                                    NaN               NaN
# 631                             170.439353      1.900458e+08
#
#       Average Cost Per Unit (Weighted), 2012  Beneficiary Count No LIS, 2012  \
# 4388                                9.579561                           850.0
# 4387                                9.837167                            94.0
# 3183                                3.914562                        190250.0
# 302                                      NaN                             NaN
# 631                                 0.653632                        561719.0
#
#       Average Beneficiary Cost Share No LIS, 2012  \
# 4388                                   655.753659
# 4387                                   383.224043
# 3183                                   283.400822
# 302                                           NaN
# 631                                     53.357370
#
#       Beneficiary Count LIS, 2012  Average Beneficiary Cost Share LIS, 2012  \
# 4388                        884.0                                 13.664717
# 4387                         88.0                                  7.897159
# 3183                      89745.0                                 23.853139
# 302                           NaN                                       NaN
# 631                      167103.0                                  6.620163
#
#       Claim Count, 2013  Total Spending, 2013  Beneficiary Count, 2013  \
# 4388             7413.0          1.516217e+07                   1621.0
# 4387              676.0          1.158369e+06                    209.0
# 3183          1597133.0          3.040931e+08                 293723.0
# 302                 NaN                   NaN                      NaN
# 631           4356965.0          1.308574e+08                 875680.0
#
#       Total Annual Spending Per User, 2013  Unit Count, 2013  \
# 4388                           9353.590358      1.045439e+06
# 4387                           5542.437608      7.926100e+04
# 3183                           1035.305591      8.112729e+07
# 302                                    NaN               NaN
# 631                             149.435199      2.309080e+08
#
#       Average Cost Per Unit (Weighted), 2013  Beneficiary Count No LIS, 2013  \
# 4388                               14.503161                           904.0
# 4387                               14.614621                           113.0
# 3183                                3.748345                        209863.0
# 302                                      NaN                             NaN
# 631                                 0.566720                        690330.0
#
#       Average Beneficiary Cost Share No LIS, 2013  \
# 4388                                   709.687412
# 4387                                   441.129027
# 3183                                   287.321800
# 302                                           NaN
# 631                                     49.613147
#
#       Beneficiary Count LIS, 2013  Average Beneficiary Cost Share LIS, 2013  \
# 4388                        717.0                                 17.607894
# 4387                         96.0                                 10.497292
# 3183                      83860.0                                 24.262862
# 302                           NaN                                       NaN
# 631                      185350.0                                  6.597276
#
#       Claim Count, 2014  Total Spending, 2014  Beneficiary Count, 2014  \
# 4388             6409.0          1.683369e+07                   1291.0
# 4387              784.0          1.812725e+06                    225.0
# 3183          1494976.0          3.183214e+08                 277616.0
# 302                 NaN                   NaN                      NaN
# 631           4806144.0          1.076669e+08                 997474.0
#
#       Total Annual Spending Per User, 2014  Unit Count, 2014  \
# 4388                          13039.263292      9.139120e+05
# 4387                           8056.554711      9.875100e+04
# 3183                           1146.624856      6.931393e+07
# 302                                    NaN               NaN
# 631                             107.939572      2.634679e+08
#
#       Average Cost Per Unit (Weighted), 2014  Beneficiary Count No LIS, 2014  \
# 4388                               18.419376                           717.0
# 4387                               18.356521                           106.0
# 3183                                4.592460                        200416.0
# 302                                      NaN                             NaN
# 631                                 0.408653                        788488.0
#
#       Average Beneficiary Cost Share No LIS, 2014  \
# 4388                                   920.585439
# 4387                                   530.618868
# 3183                                   297.687050
# 302                                           NaN
# 631                                     47.667746
#
#       Beneficiary Count LIS, 2014  Average Beneficiary Cost Share LIS, 2014  \
# 4388                        574.0                                 13.952666
# 4387                        119.0                                 11.141176
# 3183                      77200.0                                 23.141024
# 302                           NaN                                       NaN
# 631                      208986.0                                  6.210627
#
#       Claim Count, 2015  Total Spending, 2015  Beneficiary Count, 2015  \
# 4388             5188.0          1.774046e+07                   1042.0
# 4387             1256.0          4.051933e+06                    423.0
# 3183          1044439.0          2.525857e+08                 222735.0
# 302            138714.0          2.888796e+07                  99047.0
# 631           5430791.0          1.008682e+08                1146771.0
#
#       Total Annual Spending Per User, 2015  Unit Count, 2015  \
# 4388                          17025.395701      7.225070e+05
# 4387                           9579.036998      1.653340e+05
# 3183                           1134.018760      4.840088e+07
# 302                             291.659124      7.415621e+06
# 631                              87.958480      3.057757e+08
#
#       Average Cost Per Unit (Weighted), 2015  Beneficiary Count No LIS, 2015  \
# 4388                               24.554035                           576.0
# 4387                               24.507558                           230.0
# 3183                                5.218618                        157929.0
# 302                                 3.895555                         72464.0
# 631                                 0.329881                        906487.0
#
#       Average Beneficiary Cost Share No LIS, 2015  \
# 4388                                  1174.856441
# 4387                                   442.614478
# 3183                                   282.783150
# 302                                     53.194215
# 631                                     43.311182
#
#       Beneficiary Count LIS, 2015  Average Beneficiary Cost Share LIS, 2015  \
# 4388                        466.0                                 17.853004
# 4387                        193.0                                  5.556062
# 3183                      64806.0                                 20.283508
# 302                       26583.0                                  2.019110
# 631                      240284.0                                  6.099903
#
#       Annual Change in Average Cost Per Unit, 2015 NONPROPRIETARYNAME  \
# 4388                                      0.333055           ZILEUTON
# 4387                                           NaN           ZILEUTON
# 3183                                      0.136345        DUTASTERIDE
# 302                                            NaN        DUTASTERIDE
# 631                                      -0.192763        FINASTERIDE
#
#                                           PHARM_CLASSES
# 4388  5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase ...
# 4387  5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase ...
# 3183  5-alpha Reductase Inhibitor [EPC],5-alpha Redu...
# 302   5-alpha Reductase Inhibitor [EPC],5-alpha Redu...
# 631   5-alpha Reductase Inhibitor [EPC],5-alpha Redu...

# %%
df.shape,df_part_d.shape
# Out:
# ((4498, 55), (4498, 53))

# %%
df['PHARM_CLASSES'].fillna('Unknown',inplace=True)

# %%
df[df['PHARM_CLASSES'] == 'Unknown']['Generic Name']
# Out:
# 1                           PEN NEEDLE, DIABETIC
# 4                   CYCLOPENTOLATE HYDROCHLORIDE
# 5                 DESMOPRESSIN (NONREFRIGERATED)
# 7                      SULFURIC ACID/SULF PHENOL
# 10                 TETANUS AND DIPHTHERIA TOX/PF
# 11                 CHLORPHENIRAMINE/PHENYLEPH/DM
# 15                  CHLOR-MAL/PHENYLEPH/METHSCOP
# 17                BACITRACIN/POLYMYXIN B SULFATE
# 19                 PERIT. DIALYSIS#6 & DEX 1.5 %
# 20                                    PREDNISONE
# 26                   MEPERIDINE HYDROCHLORIDE/PF
# 29                    LIDOCAINE HYDROCHLORIDE/PF
# 36                VALPROIC ACID (AS SODIUM SALT)
# 38                VALPROIC ACID (AS SODIUM SALT)
# 43                          LEVOMEFOLATE CALCIUM
# 44         NETUPITANT/PALONOSETRON HYDROCHLORIDE
# 45                        LEVOMEFOLATE/ALGAL OIL
# 46                        CYTARABINE LIPOSOME/PF
# 53                 TRIAMCINOLONE/DIMETH/SILICONE
# 54                           DICLOFENAC/CAPSICUM
# 55                 TRIAMCINOLONE/DIMETH/SILICONE
# 60                       FLUOCINOLONE/SHOWER CAP
# 61                 HYDROCORTISONE/SKIN CLNSR #35
# 62                TRIAMCINOLONE/EMOLLIENT CMB#86
# 69      PHENYLEPHRINE HYDROCHLORIDE/DIHYDROCO BT
# 70                DESMOPRESSIN (NONREFRIGERATED)
# 72                 DESOGESTREL-ETHINYL ESTRADIOL
# 73                 DESOGESTREL-ETHINYL ESTRADIOL
# 74                 DESOG-E.ESTRADIOL/E.ESTRADIOL
# 78                DESONIDE/EMOLLIENT COMBO.NO 28
#                           ...
# 5028                HYDROCORTISONE SOD SUCCINATE
# 5029                NORETHINDRONE-ETHINYL ESTRAD
# 5030               DESOGESTREL-ETHINYL ESTRADIOL
# 5033                CYCLOPENTOLATE HYDROCHLORIDE
# 5034                CYCLOPENTOLATE/PHENYLEPHRINE
# 5035                CYCLOPENTOLATE HYDROCHLORIDE
# 5036                        CYCLOPHOSPHATEHAMIDE
# 5037                                 CYCLOSERINE
# 5040                        PEN NEEDLE, DIABETIC
# 5041                      CYCLOSPORINE, MODIFIED
# 5042                      CYCLOSPORINE, MODIFIED
# 5046                CYPROHEPTADINE HYDROCHLORIDE
# 5052              METHENAM/BENZ AC/SALICY/SAL-AM
# 5053                        PEN NEEDLE, DIABETIC
# 5055                               CYTARABINE/PF
# 5056              CYTOMEGALOVIRUS IMMUNE GLOBULN
# 5061                  CITRIC ACID/SODIUM CITRATE
# 5062              SOD/POT/K CIT/SOD CIT/CIT ACID
# 5063               POTASSIUM CITRATE/CITRIC ACID
# 5065                           ERYTHROMYCIN BASE
# 5069                 DACLATASVIR DIHYDROCHLORIDE
# 5071                CHLOR-MAL/PHENYLEPH/METHSCOP
# 5072                CHLOR-MAL/PHENYLEPH/METHSCOP
# 5073                   DALBAVANCIN HYDROCHLORIDE
# 5077               BALANCED SALT IRRIG SOLN NO.2
# 5079              DIPH,PERTUSS(ACELL),TET PED/PF
# 5081              MTH/ME BLUE/SOD PHOS/PHEN/HYOS
# 5082              MTH/ME BLUE/SOD PHOS/PHEN/HYOS
# 5084                NORETHINDRONE-ETHINYL ESTRAD
# 5086              L-NORGEST/E.ESTRADION-E.ESTRAD
# Name: Generic Name, dtype: object

# %%
df.to_csv('data/part_d_with_uses.csv')

# %% [markdown]
# We will group by the pharm_classes, and sum over the values (dropping averages, since they don't sum that way)

# %%
grouped = df.groupby('PHARM_CLASSES')
df_use_base = grouped.aggregate(np.nansum)
years = [2011,2012,2013,2014,2015]
averages_cols = ['Average Cost Per Unit (Weighted), ',
            'Average Beneficiary Cost Share No LIS, ',
            'Average Beneficiary Cost Share LIS, ']
df_use_base.drop([avg+str(yr) for yr in years for avg in averages_cols]
                 +['Brand Name','Generic Name',
                   'Annual Change in Average Cost Per Unit, 2015'],axis=1,inplace=True)

# %%
df_use_base.shape
# Out:
# (445, 35)

# %%
df_use_base.head()
# Out:
#                                                     Claim Count, 2011  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...             7962.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          5030612.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...            23339.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...             5635.0
# Acetylcholine Releasing Agent [EPC],Increased A...               34.0
#
#                                                     Total Spending, 2011  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...          5.406118e+06
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          4.190362e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...          2.887068e+06
# Acetylcholine Release Inhibitor [EPC],Acetylcho...          6.661903e+06
# Acetylcholine Releasing Agent [EPC],Increased A...          2.016420e+03
#
#                                                     Beneficiary Count, 2011  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                   1950.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                 947130.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                   7987.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                   3051.0
# Acetylcholine Releasing Agent [EPC],Increased A...                      0.0
#
#                                                     Total Annual Spending Per User, 2011  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                           4255.233843
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                           2103.836100
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                            715.150400
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                           3884.767180
# Acetylcholine Releasing Agent [EPC],Increased A...                              0.000000
#
#                                                     Unit Count, 2011  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...      9.978270e+05
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...      2.348624e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...      7.801222e+05
# Acetylcholine Release Inhibitor [EPC],Acetylcho...      1.181800e+04
# Acetylcholine Releasing Agent [EPC],Increased A...      8.990000e+03
#
#                                                     Beneficiary Count No LIS, 2011  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                           903.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                        695061.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                          2401.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                          1294.0
# Acetylcholine Releasing Agent [EPC],Increased A...                             0.0
#
#                                                     Beneficiary Count LIS, 2011  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                       1047.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                     251962.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                       5586.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                       1727.0
# Acetylcholine Releasing Agent [EPC],Increased A...                          0.0
#
#                                                     Claim Count, 2012  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...             8310.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          5287304.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...            24057.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...             7541.0
# Acetylcholine Releasing Agent [EPC],Increased A...               29.0
#
#                                                     Total Spending, 2012  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...          1.014786e+07
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          3.877246e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...          2.871170e+06
# Acetylcholine Release Inhibitor [EPC],Acetylcho...          8.709997e+06
# Acetylcholine Releasing Agent [EPC],Increased A...          2.045950e+03
#
#                                                     Beneficiary Count, 2012  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                   1916.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                1010171.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                   7149.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                   3981.0
# Acetylcholine Releasing Agent [EPC],Increased A...                      0.0
#
#                                                     Total Annual Spending Per User, 2012  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                           9148.808431
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                           2223.340712
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                            795.013585
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                           3617.001597
# Acetylcholine Releasing Agent [EPC],Increased A...                              0.000000
#
#                                                     Unit Count, 2012  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...      1.057492e+06
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...      2.574083e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...      8.249415e+05
# Acetylcholine Release Inhibitor [EPC],Acetylcho...      1.479140e+04
# Acetylcholine Releasing Agent [EPC],Increased A...      9.060000e+03
#
#                                                     Beneficiary Count No LIS, 2012  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                           944.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                        752804.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                          2533.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                          1884.0
# Acetylcholine Releasing Agent [EPC],Increased A...                             0.0
#
#                                                     Beneficiary Count LIS, 2012  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                        972.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                     257230.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                       4616.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                       2097.0
# Acetylcholine Releasing Agent [EPC],Increased A...                          0.0
#
#                                                     Claim Count, 2013  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...             8089.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          5960487.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...            26051.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...            11134.0
# Acetylcholine Releasing Agent [EPC],Increased A...               20.0
#
#                                                     Total Spending, 2013  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...          1.632054e+07
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          4.361689e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...          3.012239e+06
# Acetylcholine Release Inhibitor [EPC],Acetylcho...          1.281318e+07
# Acetylcholine Releasing Agent [EPC],Increased A...          1.647630e+03
#
#                                                     Beneficiary Count, 2013  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                   1830.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                1170985.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                   7510.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                   5688.0
# Acetylcholine Releasing Agent [EPC],Increased A...                      0.0
#
#                                                     Total Annual Spending Per User, 2013  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                          14896.027965
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                           2386.623519
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                            857.123733
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                           3947.576300
# Acetylcholine Releasing Agent [EPC],Increased A...                              0.000000
#
#                                                     Unit Count, 2013  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...      1.124700e+06
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...      3.124059e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...      8.987575e+05
# Acetylcholine Release Inhibitor [EPC],Acetylcho...      2.111800e+04
# Acetylcholine Releasing Agent [EPC],Increased A...      7.600000e+03
#
#                                                     Beneficiary Count No LIS, 2013  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                          1017.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                        901569.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                          3018.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                          2817.0
# Acetylcholine Releasing Agent [EPC],Increased A...                             0.0
#
#                                                     Beneficiary Count LIS, 2013  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                        813.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                     269390.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                       4492.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                       2871.0
# Acetylcholine Releasing Agent [EPC],Increased A...                          0.0
#
#                                                     Claim Count, 2014  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...             7193.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          6307170.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...            26514.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...            14284.0
# Acetylcholine Releasing Agent [EPC],Increased A...               24.0
#
#                                                     Total Spending, 2014  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...          1.864641e+07
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          4.272494e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...          2.755405e+06
# Acetylcholine Release Inhibitor [EPC],Acetylcho...          1.694227e+07
# Acetylcholine Releasing Agent [EPC],Increased A...          1.822860e+03
#
#                                                     Beneficiary Count, 2014  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                   1516.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                1276560.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                   7486.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                   7051.0
# Acetylcholine Releasing Agent [EPC],Increased A...                      0.0
#
#                                                     Total Annual Spending Per User, 2014  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                          21095.818003
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                           2112.467898
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                            768.675965
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                           5845.786390
# Acetylcholine Releasing Agent [EPC],Increased A...                              0.000000
#
#                                                     Unit Count, 2014  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...      1.012663e+06
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...      3.331540e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...      9.150344e+05
# Acetylcholine Release Inhibitor [EPC],Acetylcho...      2.620700e+04
# Acetylcholine Releasing Agent [EPC],Increased A...      8.752000e+03
#
#                                                     Beneficiary Count No LIS, 2014  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                           823.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                        990204.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                          3264.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                          3339.0
# Acetylcholine Releasing Agent [EPC],Increased A...                             0.0
#
#                                                     Beneficiary Count LIS, 2014  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                        693.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                     286356.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                       4222.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                       3712.0
# Acetylcholine Releasing Agent [EPC],Increased A...                          0.0
#
#                                                     Claim Count, 2015  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...             6444.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          6619473.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...            27870.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...            17599.0
# Acetylcholine Releasing Agent [EPC],Increased A...               34.0
#
#                                                     Total Spending, 2015  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...          2.179239e+07
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...          3.835684e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...          2.704885e+06
# Acetylcholine Release Inhibitor [EPC],Acetylcho...          2.146734e+07
# Acetylcholine Releasing Agent [EPC],Increased A...          1.944510e+03
#
#                                                     Beneficiary Count, 2015  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                   1465.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                1469893.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                   7879.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                   8311.0
# Acetylcholine Releasing Agent [EPC],Increased A...                      0.0
#
#                                                     Total Annual Spending Per User, 2015  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                          26604.432699
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                           2428.968618
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                            881.616864
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                           7704.994357
# Acetylcholine Releasing Agent [EPC],Increased A...                              0.000000
#
#                                                     Unit Count, 2015  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...      8.878410e+05
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...      3.619368e+08
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...      9.837555e+05
# Acetylcholine Release Inhibitor [EPC],Acetylcho...      3.167100e+04
# Acetylcholine Releasing Agent [EPC],Increased A...      8.540000e+03
#
#                                                     Beneficiary Count No LIS, 2015  \
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                           806.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                       1138077.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                          3379.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                          3852.0
# Acetylcholine Releasing Agent [EPC],Increased A...                             0.0
#
#                                                     Beneficiary Count LIS, 2015
# PHARM_CLASSES
# 5-Lipoxygenase Inhibitor [EPC],5-Lipoxygenase I...                        659.0
# 5-alpha Reductase Inhibitor [EPC],5-alpha Reduc...                     331816.0
# Acetyl Aldehyde Dehydrogenase Inhibitors [MoA],...                       4466.0
# Acetylcholine Release Inhibitor [EPC],Acetylcho...                       4459.0
# Acetylcholine Releasing Agent [EPC],Increased A...                          0.0

# %%
df_use_base.to_csv('data/part_D_aggregated_over_uses.csv')

# %% [markdown]
# Let's do some quick visualization:

# %%
columns_of_interest = ['Total Spending, ','Claim Count, ']
years = [2012,2013,2014,2015]
for column in columns_of_interest:
    df_use_base[column+'Max'] = np.abs(df_use_base[[column+str(yr) for yr in years]]).max(axis=1)

# %%
num_top = 25
for column in columns_of_interest:
    df_sorted = df_use_base.sort_values(by=column+'Max',ascending=False)
    
    
    #mask = (result['value'].div(result['value'].sum()).cumsum() < 0.9)
    result = df_sorted[:num_top].append(pd.Series(df_sorted[num_top:].sum(axis=0), name='Other'))

    #result[[column
    #         +str(yr) for yr in years]].plot.bar(figsize = (10,6))
    result[[column+str(yr) for yr in years]].transpose().plot.area()
    plt.legend(loc=(1,0))
    plt.xticks(years,years,rotation='vertical')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# //anaconda/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# //anaconda/lib/python3.5/site-packages/mpld3/_display.py in <lambda>(fig, kwds)
#     387     formatter = ip.display_formatter.formatters['text/html']
#     388     formatter.for_type(Figure,
# --> 389                        lambda fig, kwds=kwargs: fig_to_html(fig, **kwds))
#     390
#     391
#
# //anaconda/lib/python3.5/site-packages/mpld3/_display.py in fig_to_html(fig, d3_url, mpld3_url, no_extras, template_type, figid, use_http, **kwargs)
#     234                            d3_url=d3_url,
#     235                            mpld3_url=mpld3_url,
# --> 236                            figure_json=json.dumps(figure_json),
#     237                            extra_css=extra_css,
#     238                            extra_js=extra_js)
#
# //anaconda/lib/python3.5/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     228         cls is None and indent is None and separators is None and
#     229         default is None and not sort_keys and not kw):
# --> 230         return _default_encoder.encode(obj)
#     231     if cls is None:
#     232         cls = JSONEncoder
#
# //anaconda/lib/python3.5/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# //anaconda/lib/python3.5/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# //anaconda/lib/python3.5/json/encoder.py in default(self, o)
#     178
#     179         """
# --> 180         raise TypeError(repr(o) + " is not JSON serializable")
#     181
#     182     def encode(self, o):
#
# TypeError: 2012 is not JSON serializable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# //anaconda/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# //anaconda/lib/python3.5/site-packages/mpld3/_display.py in <lambda>(fig, kwds)
#     387     formatter = ip.display_formatter.formatters['text/html']
#     388     formatter.for_type(Figure,
# --> 389                        lambda fig, kwds=kwargs: fig_to_html(fig, **kwds))
#     390
#     391
#
# //anaconda/lib/python3.5/site-packages/mpld3/_display.py in fig_to_html(fig, d3_url, mpld3_url, no_extras, template_type, figid, use_http, **kwargs)
#     234                            d3_url=d3_url,
#     235                            mpld3_url=mpld3_url,
# --> 236                            figure_json=json.dumps(figure_json),
#     237                            extra_css=extra_css,
#     238                            extra_js=extra_js)
#
# //anaconda/lib/python3.5/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     228         cls is None and indent is None and separators is None and
#     229         default is None and not sort_keys and not kw):
# --> 230         return _default_encoder.encode(obj)
#     231     if cls is None:
#     232         cls = JSONEncoder
#
# //anaconda/lib/python3.5/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# //anaconda/lib/python3.5/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# //anaconda/lib/python3.5/json/encoder.py in default(self, o)
#     178
#     179         """
# --> 180         raise TypeError(repr(o) + " is not JSON serializable")
#     181
#     182     def encode(self, o):
#
# TypeError: 2012 is not JSON serializable

# %%
import mpld3

# %%
trans_res.as_matrix()
# Out:
# array([[  1.92700709e+08,   8.50991340e+07,   5.79803270e+07,
#           3.68833650e+07,   4.02411390e+07,   4.00849200e+06,
#           3.65789490e+07,   3.55191470e+07,   3.77688260e+07,
#           2.75278970e+07,   2.42114280e+07,   2.65893860e+07,
#           2.33388640e+07,   2.19057230e+07,   1.84918800e+07,
#           2.20793890e+07,   2.08427670e+07,   1.57334830e+07,
#           1.82772650e+07,   1.74321280e+07,   1.71292890e+07,
#           1.61490710e+07,   1.54680650e+07,   8.81595300e+06,
#           1.16134270e+07,   3.82191331e+08],
#        [  2.08912645e+08,   9.35750460e+07,   6.27965160e+07,
#           4.12950390e+07,   4.31363670e+07,   3.94703340e+07,
#           3.98552560e+07,   3.96403950e+07,   4.05216010e+07,
#           3.10172840e+07,   2.81578770e+07,   2.91299480e+07,
#           2.60256280e+07,   2.59135500e+07,   2.19324680e+07,
#           2.43014950e+07,   2.21294090e+07,   1.79996670e+07,
#           1.97169000e+07,   1.83122440e+07,   1.80759890e+07,
#           1.68209040e+07,   1.60120960e+07,   1.16796500e+07,
#           1.31641370e+07,   4.19821593e+08],
#        [  2.11286436e+08,   9.70063250e+07,   6.37225080e+07,
#           4.35558000e+07,   4.39296060e+07,   4.27523020e+07,
#           4.15645260e+07,   4.10988380e+07,   4.06635190e+07,
#           3.32380860e+07,   3.04610780e+07,   2.97637540e+07,
#           2.78988020e+07,   2.75539950e+07,   2.48105610e+07,
#           2.49984140e+07,   2.28065240e+07,   1.91965840e+07,
#           1.97725000e+07,   1.75832070e+07,   1.79940690e+07,
#           1.64867150e+07,   1.57961150e+07,   1.38595950e+07,
#           1.39503960e+07,   4.33589885e+08],
#        [  2.10879488e+08,   9.96938040e+07,   6.42716030e+07,
#           4.52018050e+07,   4.42425330e+07,   4.41832150e+07,
#           4.29672830e+07,   4.26429440e+07,   4.00007250e+07,
#           3.43929960e+07,   3.18852840e+07,   3.03682470e+07,
#           2.95292980e+07,   2.90479770e+07,   2.76808580e+07,
#           2.55571190e+07,   2.32401560e+07,   2.05634900e+07,
#           1.93639830e+07,   1.68166860e+07,   1.79381860e+07,
#           1.63319290e+07,   1.55922530e+07,   1.55233420e+07,
#           1.45717490e+07,   4.45976441e+08]])

# %%
fig, ax = plt.subplots()
trans_res = result[[column+str(yr) for yr in years]].transpose()
area = ax.stackplot([2012,2013,2014,2015],trans_res.as_matrix().T)
labels = list(result.index)
tooltip = mpld3.plugins.PointLabelTooltip(area, labels=labels)
mpld3.plugins.connect(fig, tooltip)

mpld3.enable_notebook()

# %%
result[[column+str(yr) for yr in years]].transpose().plot.area()
plt.legend(loc=(1,0))
plt.xticks(rotation='vertical')
# Out:
# (array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ]),
#  <a list of 7 Text xticklabel objects>)

# %%
fig, ax = plt.subplots()
trans_res = result[[column+str(yr) for yr in years]].transpose()
ax.stackplot(trans_res)
result[[column+str(yr) for yr in years]].transpose().plot.area()
plt.legend(loc=(1,0))
plt.xticks(rotation='vertical')


fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
N = 100

scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s=1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)
ax.grid(color='white', linestyle='solid')

ax.set_title("Scatter Plot (with tooltips!)", size=20)

labels = ['point {0}'.format(i + 1) for i in range(N)]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)

mpld3.enable_notebook()
# Out:
# (array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ]),
#  <a list of 7 Text xticklabel objects>)

# %%
plt.get_
