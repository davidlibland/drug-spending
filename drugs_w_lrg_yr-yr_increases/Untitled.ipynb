# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://query.data.world/s/1jckku39d0p78m8jm1gnvww5t')

# %%
df.shape
# Out:
# (4498, 53)

# %%
df.plot(kind='area',)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-221887f6f6b7> in <module>()
# ----> 1 df.plot(kind='area')
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in generate(self)
#    1041         self._compute_plot_data()
#    1042         self._setup_subplots()
# -> 1043         self._make_plot()
#    1044         self._add_table()
#    1045         self._make_legend()
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in _make_plot(self)
#    1724                              stacking_id=stacking_id,
#    1725                              is_errorbar=is_errorbar,
# -> 1726                              **kwds)
#    1727             self._add_legend_handle(newlines[0], label, index=i)
#    1728
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1851         if column_num == 0:
#    1852             cls._initialize_stacker(ax, stacking_id, len(y))
# -> 1853         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds['label'])
#    1854
#    1855         # need to remove label, because subplots uses mpl legend as it is
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in _get_stacked_values(cls, ax, stacking_id, values, label)
#    1800                          'all positive or negative.'
#    1801                          '{0} contains both positive and negative values'
# -> 1802                          .format(label))
#    1803
#    1804     @classmethod
#
# ValueError: When stacked is True, each column must be either all positive or negative.Annual Change in Average Cost Per Unit, 2015 contains both positive and negative values

# %%
import matplotlib.pyplot as plt
import numpy as np
import mpld3

fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
N = 100

scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s=1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)
ax.grid(color='white', linestyle='solid')

ax.set_title("Scatter Plot (with tooltips!)", size=20)

labels = ['point {0}'.format(i + 1) for i in range(N)]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)

mpld3.enable_notebook()
